# %% [markdown]
# # Студент (введите свои ФИО и номер группы)

# %% [markdown]
# # Лабораторная - Применение потоковых методов обработки изображений Python -Вариант "F"

# %% [markdown]
# ### Цели
# <li>**Часть 1. Ввод изображения**</li>
# <li>**Часть 2: Программирование 2d - convolution (двумерной свертки) изображения**</li>
# <li>**Часть 3: Применение двумерной свертки для обработки изображений**</li>
# ### История/Cценарий
# В этой лабораторной работе вы будете исследовать алгоритм двумерной свертки изображений
# ### Необходимые ресурсы
# * 1 ПК с доступом в Интернет
# * Библиотеки Python: numpy, matplotlib, scimage
# * Файл данных: coins.png

# %% [markdown]
# #### Шаг 1.  Импорт необходимых библиотек Python.
# На этом этапе вы  импортируете библиотеки Python, которые потребуются для выполнения практического задания.

# %%
#Ячейка №1
import skimage
import os
import matplotlib.pyplot as plt
from skimage import io
from skimage import data
from skimage.viewer import ImageViewer
# !pip install opencv-python
import numpy as np
import cv2
import matplotlib.pyplot as plt
# Out:
# C:\Users\supermen\Anaconda3\lib\site-packages\skimage\viewer\utils\core.py:10: UserWarning: Recommended matplotlib backend is `Agg` for full skimage.viewer functionality.
#   warn("Recommended matplotlib backend is `Agg` for full "
# ...
# You are using pip version 10.0.1, however version 18.1 is available.
# You should consider upgrading via the 'python -m pip install --upgrade pip' command.

# %% [markdown]
# #### Шаг 2.  Создание объекта-изображения из файла .png
# Используя функцию imread() библиотеки io сформируйте объект-изображение canvas

# %%
#Ячейка №2
#filename = 'coins.png'
coins = #...

# %% [markdown]
# #### Шаг 3.  Отображение типа объекта-изображения
# Используя функцию type() отобразите тип объекта-изображения coins

# %%
#Ячейка №3
#...

# %% [markdown]
# #### Шаг 4.  Отображение структуры объекта-изображения
# Используя метод shape отобразите структуру объекта-изображения coins

# %%
#Ячейка №4
#...

# %% [markdown]
# #### Шаг 5.  Обесцвечивание объекта-изображения.
# Создайте объект "gray" с использованием функции cv2.cvtColor для преобразования цветного изображения в изображение с оттенками серого и отобразите его во вьюере ячейки

# %%
#Ячейка №5
#...

# %% [markdown]
# #### Шаг 6. Определите функцию для преобразования изображения по методу convolution (псевдо-свертка)
#
# Определите функцию, которая формирует выходное изображение (Output) выполняя двумерную свертку входного изображения (input) с ядром (Kernel) 3x3 пиксела по приведенной ниже схеме:
# <img src="convolve-s.jpg">

# %%
#Ячейка №6
def quonvolve2d(image, kernel):
    # This function which takes an image and a kernel 
    # and returns the convolution of them
    # Args:
    #   image: a numpy array of size [image_height, image_width].
    #   kernel: a numpy array of size [kernel_height, kernel_width].
    # Returns:
    #   a numpy array of size [image_height, image_width] (convolution output).
    
        #...# Flip the kernel
         #...     # convolution output
# Add zero padding to the input image
    #...
    #...
# Image normalization 
    #...     # Loop over every pixel of the image
        #...
            #...
# Image conversion                 
  # Loop over every pixel of the image
    #...
    #...
            # element-wise multiplication of the kernel and the image
            #...
    return output

# %% [markdown]
# #### Шаг 7. Проверьте работоспособность функции псевдо-свертки, применив ее к объекту gray с ядром equivalence (Тождество):
# <li>**0,0,0**</li>
# <li>**0,1,0**</li>
# <li>**0,0,0**</li>
# отобразите результат во вьюере ячейки

# %%
#Ячейка №7
#...
# Out:
# []

# %% [markdown]
# #### Шаг 8. Примените функцию псевдо-свертки объекту gray с ядром sharpen (Выделение граней):
# <li>**0,-1,0**</li>
# <li>**-1,5,-1**</li>
# <li>**0,-1,0**</li>
# отобразите результат во вьюере ячейки

# %%
#Ячейка №8
#...
# Out:
# []

# %% [markdown]
# #### Шаг 9. Примените функцию псевдо-свертки объекту gray с ядром  soften (сглаживание):
# <li>**1,1,1**</li>
# <li>**1,1,1**</li>
# <li>**1,1,1**</li>
# отобразите результат во вьюере ячейки и оконном вьюере

# %%
#Ячейка №9
#...
# Out:
# []

# %% [markdown]
# #### Шаг 9а*.  Пороговая нормализация объекта-изображения
# С помощью функции copy() создайте объект canvas_mask и замените в нем начения выше 150  на 255 (белый). Отобразите нормализованный объект во вьюере ячейки.

# %%
#Ячейка №9а
#mask2 = canvas > 150
#canvas_mask = canvas.copy()
#canvas_mask[mask2] = 255
#plt.imshow(canvas_mask)
#plt.show()

# %% [markdown]
# #### Шаг 10*.  Обработка оригинального изображения
# Создайте или найдите собственный файл исходного изображения и повторите для него действия, указанные в ячейках 2-5, 7-9
# Создайте собственное (или найдите неиспользованное в шагах 7-9) ядро свертки и примените его к оригинальному изображению. Поясните полученные результаты.

# %%
#Ячейка №10
